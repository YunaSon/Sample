# %% [markdown]
# <h1> <font color='skyblue'> Data Visualization </font> </h1>
#
# <h3> Python libraries</h3>
# <li>Matplotlib</li>
# <li>Pandas</li>
# <li>Seaborn</li>
#
# <h3> Basic Static Graphs </h3>
# <li>막대 그래프(BarGraph)</li>
# <li>선 그래프(lineGraph)</li>
# <li>히스토그램(Histogram)</li>
# <li>상자그림(BoxPlot)</li>
# <li>기타....원그래프, heatmap...</li>

# %% [markdown]
# <p>------------------------------------------------------------------------------------------</p>

# %% [markdown]
# <h2> <font color='orange'> Samples </font> </h2>

# %% [markdown]
# ### <font color='orange'> 막대 그래프(BarGraph) </font>

# %% [markdown]
# 막대그래프는 범주형 데이터의 수치를 요약한다. 일반적으로 가로, 세로, 누적, 그룹화된 막대 그래프 등을 사용한다.

# %%
import matplotlib.pyplot as plt
region = ['A', 'B', 'C', 'D', 'E']
sales = [113, 90, 401, 100, 300]
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.bar(region_index, sales, align='center', color='darkblue')
plt.xticks(region_index, region, rotation=0, fontsize='small')
plt.xlabel('Customer Name')
plt.ylabel('Sale Amount')
plt.title('Sale Amount per Customer')
plt.savefig('bar_plot.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
customers = ['ABC', 'DEF', 'GHI', 'JKL', 'MNO']
customers_index = range(len(customers))
sale_amounts = [123, 90, 201, 111, 232]

# %% [markdown]
# 그래프에 사용할 데이터를 만든다.
# customers가 x축, sales_amounts가 y축이다.
# xticks함수에는 인덱스와 레이블이 모두 필요하기 때문에 index도 같이 만들었다.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.bar(customers_index, sale_amounts, align='center', color='darkblue')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 그래프를 만들기 위해서는, 먼저 하나의 그림(figure)를 만들고 그 안에 하위 그래프(subplot)을 추가해야 한다.
# 그림 하나에 둘 이상의 그래프를 추가하는 것이 가능하므로 만들 하위 그래프의 좌표를 지정한다. ax1은 유일한 (1행, 1열, 1개)하위 그래프임을 의미한다.
#
# .bar 메소드를 이용해 막대그래프를 만든다. X축은 customers_index, Y축은 sale_amounts다. align='center'는 막대가 X축 레이빌의 중앙에 위치하도록 지정하며, color는 'darkblue'는 막대의 색상을 지정한다.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.bar(customers_index, sale_amounts, align='center', color='darkblue')
ax1.xaxis.set_ticks_position('top')
ax1.yaxis.set_ticks_position('left')


plt.xticks(customers_index, customers, rotation=90, fontsize='small')
plt.xlabel('Customer Name')
plt.ylabel('Sale Amount')
plt.title('Sale Amount per Customer')
# Out:
# Text(0.5, 1.0, 'Sale Amount per Customer')

# %% [markdown]
# xaxis.set_ticks_position을 이용해서 X축, Y축의 눈금 위치를 지정할 수 있다.
# xticks를 이용해서 눈금 레이블을 인덱스에서 실제 이름의 인덱스로 변경한다.
# rotation=0은 눈금 레이블을 수평, 90은 수직으로 지정하며, fontsize='small'은 눈금 레이블의 크기를 줄인다.
#
# plt.xlabel,ylabel, tatle 을 통해 X축/Y축 레이블, 그래프 제목을 추가한다.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.bar(customers_index, sale_amounts, align='center', color='darkblue')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
plt.xticks(customers_index, customers, rotation=0, fontsize='small')
plt.xlabel('Customer Name')
plt.ylabel('Sale Amount')
plt.title('Sale Amount per Customer')

plt.savefig('hi.png', dpi=400)
plt.show()

# %% [markdown]
# plt.savefig로 완성된 그래프를 현재 폴더에 저장한다. dpi로 그림의 해상도를 지정하고, bbox_inches='tight'는 그림을 둘러싼 여백을 제거한다.

# %%
# !ls
# Out:
# Python Data Science Hnandbook Ch2
# Visualization_Matplotib_Pandas_Seaborn.ipynb
# bar_plot.png
# hi.png
# 데싸반_4주차_VisualizationWithMatplotlib.ipynb

# %% [markdown]
# ### <font color='orange'> 히스토그램(Histogram) </font>

# %% [markdown]
# 히스토그램은 수치형 데이터의 분포를 나타낸다. 흔히 빈도(도수), 빈도밀도(도수밀도), 확률, 확률밀도등의 분포를 그릴 때 사용한다.

# %%
import numpy as np
mu1, mu2, sigma = 100, 130, 15
x1 = mu1 + sigma*np.random.randn(10000)
x2 = mu2 + sigma*np.random.randn(10000)
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
patches = ax1.hist(x1, bins=50, normed=False, color='darkgreen')
patches = ax1.hist(x2, bins=50, normed=False, color='orange',alpha=0.5)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
plt.xlabel('Bins')
plt.ylabel('Number of Values in Bin')
ax1.set_title('Two Frequency Distributions')
plt.savefig('histogram.png', dip=400, bbox_inches='tight')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
mu1, mu2, sigma = 100, 130, 15
x1 = np.random.randn(1)
x2 = mu2 + sigma*np.random.randn(10000)

# %% [markdown]
# #### <font color='darkblue'> numpy의 난수 생성함수.</font>
# np.random.randn( ) : Return a sample (or samples) from the “standard normal” distribution.
#
# - np.random.randn(1) : -1 ~ 1까지 난수 1개
# - np.random.randn(100) : -1 ~ 1까지 난수 100개
# - np.random.randn(2,4) : -1 ~ 1까지의 난수 2 X 4 array (총8개)로 반환

# %%
np.random.randn(2,4)
# Out:
# array([[ 0.95636545,  1.25505583,  0.75579517, -0.98064271],
#        [-1.31621687, -0.76278472,  1.00442121, -0.54966574]])

# %% [markdown]
# x1의 평균은 100, x2의 평균은 130이므로 두 분포는 일부분만 겹치게 될 것이다.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
patches = ax1.hist(x1, bins=50, normed=False, color='green')
patches = ax1.hist(x2, bins=50, normed=False, color='skyblue',alpha=0.5)

# %% [markdown]
# #### <font color='darkblue'> 히스토그램 </font>
# 도수분포표를 그래프로 나타낸 것
#
# - 가로축
#     - 계급: 변수의 구간, bin (or bucket)
#
# - 세로축
#     - 도수: 빈도수, frequency
#
# - 전체 총 량: n
#
# x1과 x2의 평균이 100, 130이고 두 변수에 대한 히스토그램을 만든다.
# bins=50은 수치를 50개의 구간으로 표시하며, normed=False는 확률 밀도가 아니라 빈도로 표시한다.
#
# https://ttend.tistory.com/575

# %%
type(patches)
#print(patches)
# Out:
# tuple

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,2)
patches = ax1.hist(x1, bins=50, normed=False, color='green')
ax2 = fig.add_subplot(2,1,1)
patches = ax2.hist(x2, bins=50, normed=False, color='skyblue',alpha=0.5)

# %% [markdown]
# ### <font color='orange'> 선그래프(line plot) </font>

# %% [markdown]
# 선 그래프는 수치의 변화를 선으로 이어 그린다. 데이터 변화 추세를 보여주는데 많이 이용된다.

# %%
plot_data1 = np.random.randn(50).cumsum()
plot_data2 = np.random.randn(50).cumsum()
plot_data3 = np.random.randn(50).cumsum()
plot_data4 = np.random.randn(50).cumsum()

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(plot_data1, marker=r'o', color=u'blue', linestyle='-', label='Blue Solid')
ax1.plot(plot_data2, marker=r'+', color=u'red', linestyle='--', label='Red Dash')
ax1.plot(plot_data3, marker=r'*', color=u'green',linestyle='-.', label='Green Dash Dot')
ax1.plot(plot_data4, marker=r's', color=u'black', linestyle=':', label='Black Dotted')

ax1.set_tile('Line Plots: Markers, Colors, and Linestyles')
plt.xlabel('Draw')
plt.ylabel('Random Number')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6729c37c4180> in <module>
# ----> 1 plot_data1 = np.random.randn(50).cumsum()
#       2 plot_data2 = np.random.randn(50).cumsum()
#       3 plot_data3 = np.random.randn(50).cumsum()
#       4 plot_data4 = np.random.randn(50).cumsum()
#       5
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### <font color='orange'> 산점도(Scatter Plot) </font>

# %% [markdown]
# 산점도는 키와 몸무게, 수요와 공급 등 두 변수 간의 관계를 표현한다.
# 두 변수가 양의 상관관계인지 음의 상관관계인지를 파악할 수 있다.
# 또한 산점도 위에 회귀선(regression line)을 그리면 하나의 변수 값에 따라 다른 변수값이
# 어떻게 변하는지 예축할 수 있다.
#
# 회귀선: 제곱오차(squared error)를 최소화 하는 직선이다.

# %%
x = np.arange(start=1., stop=15., step=1.)
y_linear = x + 5. * np.random.randn(14)
y_quadratic = x**2 + 10*np.random.randn(14)

fn_linear = np.poly1d(np.polyfit(x,y_linear,deg=1))
fn_quadratic = np.poly1d(np.polyfit(x, y_quadratic, deg=2))

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ax1.plot(x, y_linear, 'bo', x, y_quadratic, 'go', x, fn_linear(x),'b-', x, fn_quadratic(x), 'g-', linewidth=2)
ax1.set_title('Scatter Plots with Best Fit Lines')

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x = np.arange(start=1., stop=15., step=1.)
y_linear = x + 5. * np.random.randn(14)
y_quadratic = x**2 + 10*np.random.randn(14)

# %% [markdown]
# 임의의 데이터 만들기
# 선형 다항식 및 2차 다항식의 데이터를 임의로 만든다.

# %%
y_quadratic = x**2 + 10*np.random.randn(14)
fn_linear = np.poly1d(np.polyfit(x,y_linear,deg=1))
fn_quadratic = np.poly1d(np.polyfit(x, y_quadratic, deg=2))

# %% [markdown]
# numpy의 polyfit과 poly1d함수: 다항식과 관련된 함수.
#
#  - polyfit: 제곱 오차를 최소화하는 계수 p로 구성된 벡터를 반환합니다.
# - https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html
#
#  - poly1d: 1차원 다항식
# - https://docs.scipy.org/doc/numpy/reference/generated/numpy.poly1d.html

# %%
grades = {"math" : 90, 'Science' : 85, "Korean": 100, "English": 70}

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(grades.keys(), grades.values(),marker='o')
plt.show()

# %% [markdown]
# ## <font color='orange'> 상자그림(Box Plot) </font>

# %% [markdown]
# 상자그림은 데이터에서 얻은 5가지 통계량을 가지고 만드는 그림이다.
# - 최솟값, 최댓값, 제 1사분위수, 제 2 사분위수(중앙값), 제 3 사분위수
# - 상자 맨 아래에는 제 1 사분위수, 맨 위에는 제 3 사분위수, 상자 중간에는 중앙값이 표시된다.
# - 수염(whisker): 상자 위아래의 선
# - 특이점, 이상점(Outlier): 상자 밖에 있는 data들
#
#
# https://blog.naver.com/reisei11

# %%
N = 500
normal = np.random.normal(loc=0.0, scale=1.0, size=N)
lognormal = np.random.lognormal(mean=0.0, sigma=1.0, size=N)
index_value = np.random.random_integers(low=0, high=N-1, size=N)
normal_sample = normal[index_value]
lognormal_sample = lognormal[index_value]
box_plot_data = [normal, normal_sample, lognormal, lognormal_sample]
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
box_labels = ['normal', 'normal_sample', 'lognormal', 'lognormal_sample']
ax1.boxplot(box_plot_data, notch=False, sym='.', vert=True, whis=1.5, showmeans=True, labels=box_labels)
ax1.set_title('Box Plots: Resampling of Two Distributions')
ax1.set_xlabel('Distribution')
ax1.set_ylabel('Value')
plt.show()

# %% [markdown]
# - norch = False는 상자 중간에 홈(norch)이 파이게 하지 말고 사각형으로 그리게 한다.
# - sym은 outlier를 표기할 기호를 기본값인 + 대신 .기호로 나타낸다.
# - whis는 제 1사분위수 및 제 3 사분위수를 연장한 수염의 길이를 지정한다.
# - IQR: 사분위간 범위(interqurtile range) Q3 - Q1
# - showmeans : 평균 표시 여부

# %% [markdown]
# ## <font color='green'> matplotlib 요약 </font>

# %% [markdown]
# ### <font color='blue'> 1. Figure와 subplot </font>
# - matplotlib에서 그래프는 Figure 객체 내에 존재한다.
#     - plt.figure()
#     - fig = plt.figure()
#     - 빈도화지 생성.
# - 도화지 만으로는 빈 객체로는 그래프를 만들 수 없으므로 add_subplot을 사용해 하나 이상의 서브플롯을 생성해야 한다.
#     - plt.figure().add_subplot(1, 1, 1)
#     - fig.add_subplot(1, 1, 1)
#     - ax1 = fig.add_subplot(1, 1, 1)
# - plt.plot()명령으로 matplotlib은 가장 최근의 figure객체와 그 서브플롯을 그린다.
# - 서브플롯이 없다면 서브플롯 하나를 생성한다.
#     - plt.plot(randn(50).cumsum(), 'k--')
# - 특정한 배치에 맞추어 여러 개의 서브플롯을 포함하는 Figure를 생성하는 일은 흔히 접하게 되는 업무이다. 이를 위해 plt.subplots라(x,y)는 메서드가 있다.
#     - plt.subplots(2,3)
#         - nrows: 서브플롯의 로우 수
#         - ncols: 서브플롯의 칼럼 수
#         - sharex: 모든 서브플롯이 같은 x축 눈금을 사용하도록 한다.
#         - sharey: 모든 서브플롯이 같은 y축 눈금을 사용하도록 한다.
#         - subplot_kw: add_subplot()을 사용해 각 서브플롯을 생성할 때 사용할 키워드를 담고 있는 사전
#         - **fig_kw: Figure를 생성할 때 추가적으로 생성하는 키워드 인자.
#            - 예: plt.subplots(2, 2, figsize=(8,6))

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)
ax1

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
ax1.hist(np.random.randn(100), bins=20, color='r', alpha=0.3)
# Out:
# (array([ 1.,  0.,  2.,  3.,  3.,  1.,  8.,  6., 10., 11.,  8., 13.,  3.,
#          4., 13.,  6.,  2.,  4.,  0.,  2.]),
#  array([-2.70826944, -2.44434718, -2.18042492, -1.91650266, -1.6525804 ,
#         -1.38865814, -1.12473588, -0.86081362, -0.59689136, -0.3329691 ,
#         -0.06904684,  0.19487542,  0.45879768,  0.72271994,  0.9866422 ,
#          1.25056446,  1.51448672,  1.77840898,  2.04233124,  2.3062535 ,
#          2.57017576]),
#  <a list of 20 Patch objects>)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax1.hist(np.random.randn(100), bins=20, color='r', alpha=0.3)
# Out:
# (array([ 8.,  4.,  2.,  5.,  5.,  4.,  4.,  7.,  9.,  5., 11.,  9., 10.,
#          3.,  4.,  4.,  2.,  2.,  1.,  1.]),
#  array([-1.70376962, -1.49453647, -1.28530332, -1.07607017, -0.86683702,
#         -0.65760387, -0.44837072, -0.23913757, -0.02990442,  0.17932873,
#          0.38856188,  0.59779503,  0.80702818,  1.01626133,  1.22549448,
#          1.43472763,  1.64396078,  1.85319393,  2.06242708,  2.27166023,
#          2.48089338]),
#  <a list of 20 Patch objects>)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax1.hist(np.random.randn(100), bins=20, color='r', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
#plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### <font color='blue'>2. 색상, 마커, 선스타일, 눈금, 축라벨, 범례 </font>
# - matplotlib의 plot함수는 x와 y좌표 값이 담긴 배열을 받고 추가로 색상, 선스타일 등을 나타내는 인자를 받는다.
#     - plt.plot(np.random.randn(30).cumsum(), 'g--')
# - matplotlib에서는 기본 눈금, 축 라벨 메소드를 제공한다.
#     - plt.figure().add_subplot(1, 1, 1).plot(x, y)
#     - ax.plot(x, y)
#     - ax.set_ticks([0, 250, 500, 750, 1000])
#     - ax.set_xtickslabels(['one', 'two', 'three', 'four', 'five'])
#     - ax.set_title('Title')
#     - ax.set_xlabel('Stage')
#     - ax.set_ylabel('value')
# - 범례: 그래프의 요소를 확인하기 위한 것으로 각 plot메소드에 label인자를 넘긴뒤 legend()메소드로 범례를 생성한다.
#     - ax.plot(np.random.randn(50).cumsum(), 'k', label='one')
#     - ax.legend(loc='best')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'ro', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('my plot')
ax.set_xlabel('Stages')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'r', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'b', label ='two')
ax.legend()

# %% [markdown]
# ### <font color='blue'> 3. 그래프를 파일로 저장. </font>
# Figure는 plt.savefig메서드를 이용해서 파일로 저장할 수 있다.
#     - fname: 파일 이름
#     - dpi: 해상도 (기본 100)
#     - facecolor, edge color : 서브플롯의 바깥 배경 색상, 기본값은 흰색
#     - format: 파일포맷
#     - bbox_inches: Figure에서 저장할 부분.
#       (만약에 'tight'라고 지정하면 Figure둘레의 비어있는 공간 제거.)

# %%
plt.savefig('hi.jpg',dpi=400)

# %% [markdown]
# # <font color='skyblue'> pandas의 Plot함수 </font>

# %% [markdown]
# - pandas에서도 series와 dataframe 자료형을 시각화하는 plot함수를 제공한다.
# - plot함수의 기본값은 선그래프(line Graph)이지만 kind인수를 사용해서 다른 그래프를 그릴 수 있다.
# - EX. 육각형 구간, 행렬 그래프, 밀도 그래프, 앤드루스 곡선, 평행좌표계, 시차(lag)그래프, 자기상관 그래프, 부트스트랩 그래프..
# - 이중축, 오차 막대, 데이터 테이블
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
fig, axes = plt.subplots(nrows=1, ncols=2)
ax1, ax2 = axes.ravel()

data_frame = pd.DataFrame(np.random.rand(5,3), index=['Customer1','Customer2','Customer3','Customer4','Customer5'], columns=pd.Index(['Metric1','Metric2','Metric3'], name='Metrics'))
data_frame.plot(kind='bar', ax=ax1, alpha=0.75, title='Bar Plot')

plt.setp(ax1.get_xticklabels(), rotation=45, fontsize=10)
plt.setp(ax1.get_yticklabels(), rotation=0, fontsize=10)
ax1.set_xlabel('Customer')
ax1.set_ylabel('Value')
                          
colors = dict(boxes='DarkBlue',whiskers='Gray', medians='Red', caps='Black')
data_frame.plot(kind='box',color=colors, sym='r', ax=ax2, title='Box Plot')

plt.setp(ax2.get_xticklabels(), rotation=45, fontsize=10)
plt.setp(ax2.get_yticklabels(), rotation=0, fontsize=10)

ax2.set_xlabel('Metric')
ax2.set_ylabel('Value')
                          
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
ax1, ax2 = axes.ravel()

# %% [markdown]
# 하나의 그림과 한 쌍의 하위 그래프를 만든다.
# ravel함수를 사용하여 하위 그래프를 ax1과 ax2의 두 변수로 나눴다.
# 따라서 행과 열 인덱싱(axes[0,0], axes[0,1])으로 하위 그래프를 따로 지정할 필요는 없다.

# %%
data_frame = pd.DataFrame(np.random.rand(5,3), index=['Customer1','Customer2','Customer3','Customer4','Customer5'], columns=pd.Index(['Metric1','Metric2','Metric3'], name='Metrics'))
data_frame.plot(kind='bar', ax=ax1, alpha=0.75, title='Bar Plot')

# %% [markdown]
# 도화지가 없으면...시각화는 안이루어 지고 그냥 메모리에다가만 저장 된다.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
ax1, ax2 = axes.ravel()
data_frame = pd.DataFrame(np.random.rand(5,3), index=['Customer1','Customer2','Customer3','Customer4','Customer5'], columns=pd.Index(['Metric1','Metric2','Metric3'], name='Metrics'))
data_frame.plot(kind='bar', ax=ax1, alpha=0.75, title='Bar Plot')
ax1.set_xlabel('Customer')
ax1.set_ylabel('Value')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
ax1, ax2 = axes.ravel()
data_frame = pd.DataFrame(np.random.rand(5,3), index=['Customer1','Customer2','Customer3','Customer4','Customer5'], columns=pd.Index(['Metric1','Metric2','Metric3'], name='Metrics'))
data_frame.plot(kind='bar', ax=ax1, alpha=0.75, title='Bar Plot')
ax1.set_xlabel('Customer')
ax1.set_ylabel('Value')

colors = dict(boxes='DarkBlue',whiskers='Gray', medians='Red', caps='Black')
data_frame.plot(kind='box',color=colors, sym='r', ax=ax2, title='Box Plot')

ax2.set_xlabel('Metrics')
ax2.set_ylabel('Value')
                          
plt.show()

# %% [markdown]
# colors딕셔너리를 만든다. 각 상자그림의 요소의 색상을 지정할 수 있다.

# %% [markdown]
# ### <font color='darkblue'>첫 시간에 원석님이 했던 방법으로 그리면... (titanic예제)</font>

# %%
import pandas as pd
fig, ax = plt.subplots(nrows=1, ncols=2)
#ax1, ax2 = axes.ravel()
data_frame = pd.DataFrame(np.random.rand(5,3), index=['Customer1','Customer2','Customer3','Customer4','Customer5'], columns=pd.Index(['Metric1','Metric2','Metric3'], name='Metrics'))

data_frame.plot(kind='bar', ax=ax[0], alpha=0.75, title='Bar Plot')

plt.setp(ax[0].get_xticklabels(), rotation=45, fontsize=10)
plt.setp(ax[0].get_yticklabels(), rotation=0, fontsize=10)
ax[0].set_xlabel('Customer')
ax[0].set_ylabel('Value')
                          
colors = dict(boxes='DarkBlue',whiskers='Gray', medians='Red', caps='Black')
data_frame.plot(kind='box',color=colors, sym='r', ax=ax[1], title='Box Plot')

plt.setp(ax[1].get_xticklabels(), rotation=45, fontsize=10)
plt.setp(ax[1].get_yticklabels(), rotation=0, fontsize=10)

ax[1].set_xlabel('Metric')
ax[1].set_ylabel('Value')
                          
plt.show()

# %% [markdown]
# ### <font color='orange'> 선그래프(LineGraph) </font>

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), columns=['A','B','C','D'])
df.plot()

# %% [markdown]
# - Series와 DataFrame 둘다 Plot라고 하는 Pandas의 메서드를 통해 그래프를 생성할 수 있다.
# - Plots는 기본 선그래프이다.

# %% [markdown]
# <h5> pandas.plot메서드 인자.</h5>
#
# - label: 그래프의 범례이름.
# - ax: 그래프를 그릴 matplotlib의 서브플롯 객체.
# - style: matplotlib에 전달할 'ko--'같은 스타일의 문자열
# - alpha: 투명도 (0 ~1)
# - kind: 그래프의 종류: line, bar, barh, kde
# - logy: Y축에 대한 로그스케일
# - use_index: 객체의 색인을 눈금 이름으로 사용할지의 여부
# - rot: 눈금 이름을 로테이션(0 ~ 360)
# - xticks, yticks: x축, y축으로 사용할 값
# - xlim, ylim: x축, y축 한계
# - grid: 축의 그리드 표시할 지 여부
#
# <h5> pandas의 data가 DataFrame일때 plot 메서드 인자. </h5>
#
# - subplots: 각 DataFrame의 칼럼을 독립된 서브플롯에 그린다.
# - sharex: subplots=True면 같은 X축을 공유하고 눈금과 한계를 연결한다.
# - sharey: subplots=True면 같은 Y축을 공유한다.
# - figsize: 그래프의 크기, 튜플로 지정
# - title: 그래프의 제목을 문자열로 지정
# - sort_columns: 칼럼을 알파벳 순서로 그린다.

# %% [markdown]
# ### <font color='orange'> 막대 그래프(Bar Graph) </font>

# %% [markdown]
# plot의 kind인자에 'bar'(수직 막대), 'barh'(수평 막대)로 지정한다.

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot(kind='bar', ax=axes[0], color='blue', alpha=1)
data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)

# %%
df = pd.DataFrame(np.random.rand(6,4), columns=pd.Index(['A','B','C','D']))
df.plot(kind='line')

# %%
df
# Out:
#           A         B         C         D
# 0  0.804058  0.531178  0.709405  0.577839
# 1  0.898776  0.630001  0.930188  0.458928
# 2  0.487378  0.029280  0.556710  0.848179
# 3  0.974576  0.008649  0.803570  0.406246
# 4  0.787357  0.900141  0.560420  0.668330
# 5  0.614920  0.899197  0.552649  0.787531

# %% [markdown]
# ### <font color='orange'> 히스토그램(Histogram) </font>

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips['tip_pct'].hist(bins=50)

# %%
tips['tip_pct'].plot(kind='kde')

# %% [markdown]
# - 팁 데이터를 사용해서 전체 결제 금액 대비 팁의 비율을 나타내는 히스토그램
# - 밀도 그래프: 연속된 확률분포를 나타낸다.
#     - 일반적으로는 kernels메서드를 잘 섞어서 이 분포를 근사하는 식으로 그린다.
#     - 이것은 좀 더 단순한 정규분포(가우시안)
#     - 그래서 밀도 그래프는 KDE(Kernel Density Estimate) 커널 밀도 추정 그래프.

# %% [markdown]
# - 히스토그램과 밀도 그래프는 함께 자주 사용된다.
# - 정규화된 히스토그램 위에 커널 밀도 추정 그래프를 함께 그린다.

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(2, 10, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
values.hist(bins=100, alpha=0.7, normed=True)
values.plot(kind='kde', style='k--')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# # <font color='skyblue'> seaborn 모듈 </font>

# %% [markdown]
# - seaborn은 파이썬에서 통계 그래프와 그림을 만드는 과정을 단순하게 해주는 패키지다.
# - 이 패키지는 matplotlib기반으로 만들어져 numpy와 pandas의 자료구조를 지원한다.
# - scipy및 statsmodels같은 통계분석 패키지의 기능과도 통합할 수 있다.

# %% [markdown]
# seaborn은 히스토그램, 밀도 그래프, 막대 그래프, 상자그림, 산점도 등 기본적인 통계 그래프를 만드는 기능을 제공한다. 또한 이변량 관계, 선형 및 비선형 회귀모형, 추정값의 불확실도등을 시각화할 수도 있다.
#
# 변수를 조정해가면서 변수 사이의 관계를 확인하고 복잡한 관계를 드러내는 격자 그래프를 만들 수 있다.
#
# 테마와 색상 팔레트가 내장되어 있어 그래프를 보기 좋게 꾸미기도 쉽다.
#
# matplotlib기반이므로 matplotlib의 명령어를 사용하여 그래프를 커스터마이즈할 수도 있다.

# %% [markdown]
# ### <font color='orange'> 히스토그램 </font>

# %%
import seaborn as sns

x = np.random.normal(size=1000)
sns.distplot(x, bins=20, kde=False, rug=True, label='Histogram w/o Density')
sns.utils.axlabel('Value', 'Frequency')
plt.title('Histogram of a Random Sample from a Normal Distribution')
plt.legend()
plt.show()

# %% [markdown]
# distplot함수를 사용하여 히스토그램을 만들었다.
# - 구간 개수
# - 핵밀도추정(핵함수-kernel function에 의한 확률분포의 추정)표시여부
# - 축의 러그플롯(rugplot)표시여부
# - 축레이블, 제목, 범례 등등등...

# %% [markdown]
# ### <font color='orange'> 회귀선과 일변량 히스토그램을 포함한 산점도 </font>

# %%
mean, cov = [5, 10], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
data_frame = pd.DataFrame(data, columns=['x', 'y'])
sns.jointplot(x='x', y='y', data=data_frame, kind='reg').set_axis_labels('x','y')
plt.suptitle('joint plot of Two variables with Bivariate and Univariate Graphs')
plt.show()

# %% [markdown]
# jointplot함수를 사용하여 회귀선이 있는 산점도와 각 변수의 히스토 그램을 만들었다.

# %% [markdown]
# ### <font color='orange'> 쌍별 이변량 산점도 </font>

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris)
plt.show()

tips = sns.load_dataset('tips')

# %% [markdown]
# pairplot함수 사용
# - sns내에 있는 데이터셋을 활용했다.

# %% [markdown]
# ### <font color='orange'> 여러 변수에 대한 상자그림 </font>

# %%
sns.factorplot(x='time', y='total_bill', hue='smoker', col='day', data=tips, kind='box', size=4, aspect=.5)
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# factorplot함수 사용
# - 제 3의 변수를 조정하면서 두 변수간의 관계를 나타내는 상자그림.

# %% [markdown]
# ### <font color='orange'> 부스트랩 신뢰구간을 포함한 선형 회귀모형 </font>

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# lmplot함수 사용
# - 산점도와 선형회귀선을 만들었다. 동시에 선형 회귀선 주위에 부트스트랩 신뢰구간을 표시했다.
# https://enook.jbnu.ac.kr/contents/58/#!/p/46

# %% [markdown]
# ### <font color='orange'> 부스트랩 신뢰구간을 포함한 로지스틱 회귀모형 </font>

# %%
tips['big_tip'] = (tips.tip / tips.total_bill) > .15
sns.lmplot(x='total_bill', y='big_tip', data=tips, logistic=True, y_jitter=.03).set_axis_labels('Total bill','Big Tip')
plt.title('Logistic Regression of Big Tip vs Total Bill')
plt.show()

# %% [markdown]
# lmplot함수 이용
# - 이항 종속변수에 대한 로지스틱 회귀선을 만든 그림이다.
# - y_jitter인수를 사용하여 1과 0사이의 값에 지터(jitter)를 가함으로써 X축을 따라 표시되는 점의 위치를 쉽게 알 수 있다.

# %% [markdown]
# ## 객체 지향적 해석...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ##### 2-1 plot 도화지
# plt.plot( )

# %%
# plt(matplotlib.pyplot)모듈의 plot()함수를 사용한다. 
# x축과 y축으로 된 2D의 빈 도화지(plot)가 나옵니다. 
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 2-2 그래프 그리기
# plt.plot(x, y)

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]
#plot의 인자에 x, y를 넣습니다. 
plt.plot(x, y)

# %%
#한 plot(도화지)안에 좌표를 추가하고 싶으면,
y2 = [2, 2, 2, 2]
#한번더 써줍니다. 
plt.plot(x, y)
plt.plot(x, y2)

# %% [markdown]
# #### 2.3 색상, 마커, 선스타일
# plt.plot(x, y, color='red', linestyle='--', marker='o')

# %%
#색을 바꾸고 싶으면, color라는 키워드(키워드아규먼트, **kwarg)를 이용합니다. 
#라인 스타일을 바꾸고 싶으면, linestyle라는 키워드를 이용합니다. 
plt.plot(x, y, color='red', linestyle='--')

# %% [markdown]
# #### 2.4 범례
# - plt.plot(label = '라벨 이름')
# - plt.legend( )

# %%
#라벨이라는 키워드를 지정하고, plt.legend()함수를 호출합니다.
plt.plot(x, y, color='black', linestyle='--', marker='o', label ='A')
plt.legend()

# %% [markdown]
# #### plot( )함수에 대한 설명.

# %%
#커서를 괄호에 위치후 shift + tap누르기 
plt.plot()

# %%
def print_args(*args):
    print(args)
#인자들 모으기 = arguments, args, 
#tuple의 형태로 인자를 모은다. 
#무수히 많은 인자 형태로 관리가 가능!

# %%
print_args('cap','hello','hi','craph')
# Out:
# ('cap', 'hello', 'hi', 'craph')

# %%
print_args()
# Out:
# ()

# %%
def print_kwargs(**kwargs):
    print(kwargs)
#키인자들 모으기 = keyword arguments, kwargs
#딕셔너리 형태로 인자를 모은다

# %%
print_kwargs(wine='merlot', entree='mutton', dessert='macaroon')
# Out:
# {'wine': 'merlot', 'entree': 'mutton', 'dessert': 'macaroon'}

# %%
print_kwargs()
# Out:
# {}

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set()

# %%
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)
plt.plot(x,y)
plt.legend('abcdef', ncol=2, loc='upper left')

# %%
data = np.random.multivariate_normal([0,0],[[5,2],[2,2]], size=2000)
data = pd.DataFrame(data, columns=['x','y'])

for col in 'xy':
    plt.hist(data[col], alpha=0.5)

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.distplot(data['x'])
sns.distplot(data['y'])

# %%
sns.kdeplot(data)

# %% [markdown]
# ## Annotation 예제

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.annotate('local maximum', xy=(6.38, 1), arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(6.38, 1, 'local maximum')

# %%
births = pd.read_csv('./examples/births.csv')

quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)

births.index = pd.to_datetime(10000 * births.year +
                              100 * births.month +
                              births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births',
                                    [births.index.month, births.index.day])
births_by_date.index = [pd.datetime(2012, month, day)
                        for (month, day) in births_by_date.index]

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# %%
import matplotlib as mpl

fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# Add labels to the plot
style = dict(size=10, color='gray')

ax.text('2012-1-1', 3950, "New Year's Day", **style)
ax.text('2012-7-4', 4250, "Independence Day", ha='center', **style)
ax.text('2012-9-4', 4850, "Labor Day", ha='center', **style)
ax.text('2012-10-31', 4600, "Halloween", ha='right', **style)
ax.text('2012-11-25', 4450, "Thanksgiving", ha='center', **style)
ax.text('2012-12-25', 3850, "Christmas ", ha='right', **style)

# Label the axes
ax.set(title='USA births by day of year (1969-1988)',
       ylabel='average daily births')

# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'))
