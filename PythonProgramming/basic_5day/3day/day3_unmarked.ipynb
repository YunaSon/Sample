# %% [markdown]
# # Day3 파이썬 함수

# %% [markdown]
# ### 1. 함수사용법
#
# - 함수 선언
# - 함수 호출
#
# ### 2. 함수의 의미
#
# - input과 output의 개념
# - 코드의 재사용
# - 파이썬 1등 시민: 객체..
#
#
# ### 3. input: argument, parameter
#
# ### 4. output: return이 있는 함수, return이 없는 함수
#
# ### 5. 파이썬 lambda
#
# ### 6. 하향식 설계
