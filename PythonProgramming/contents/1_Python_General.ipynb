# %% [markdown]
# # 1. Python General

# %%
from PIL import Image
img1 = Image.open('./PythonGeneral/PythonGeneral1.jpeg')
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x111D09F90>

# %%
img2 = Image.open('./PythonGeneral/PythonGeneral2.jpeg')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FA91C90>

# %%
img3 = Image.open('./PythonGeneral/PythonGeneral3.jpeg')
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FAC5D50>

# %%
img4 = Image.open('./PythonGeneral/PythonGeneral4.jpeg')
img4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FA9D590>

# %%
img5 = Image.open('./PythonGeneral/PythonGeneral5.jpeg')
img5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FAACA10>

# %%
img6 = Image.open('./PythonGeneral/PythonGeneral6.jpeg')
img6
#출처: 실전 파이썬 프로그래밍
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FAE6210>

# %%
img7 = Image.open('./PythonGeneral/PythonGeneral7.jpeg')
img7
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FAE6AD0>

# %%
img8 = Image.open('./PythonGeneral/PythonGeneral8.jpeg')
img8
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FADCED0>

# %%
img9 = Image.open('./PythonGeneral/PythonGeneral9.jpeg')
img9
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x1100F2850>

# %%
img10 = Image.open('./PythonGeneral/PythonGeneral10.jpeg')
img10
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x10FAB70D0>
